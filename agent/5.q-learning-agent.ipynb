# %%
import numpy as np
import pandas as pd
#import tensorflow as tf
import tensorflow.compat.v1 as tf
tf.disable_v2_behavior()
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
# Out:
# WARNING:tensorflow:From /Users/yutiansut/opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/compat/v2_compat.py:96: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term

# %%
df = pd.read_csv('../dataset/GOOG-year.csv')
df.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2016-11-02  778.200012  781.650024  763.450012  768.700012  768.700012
# 1  2016-11-03  767.250000  769.950012  759.030029  762.130005  762.130005
# 2  2016-11-04  750.659973  770.359985  750.560974  762.020020  762.020020
# 3  2016-11-07  774.500000  785.190002  772.549988  782.520020  782.520020
# 4  2016-11-08  783.400024  795.632996  780.190002  790.510010  790.510010
#
#     Volume
# 0  1872400
# 1  1943200
# 2  2134800
# 3  1585100
# 4  1350800

# %%
from collections import deque
import random


class Agent:
    def __init__(self, state_size, window_size, trend, skip, batch_size):
        self.state_size = state_size
        self.window_size = window_size
        self.half_window = window_size // 2
        self.trend = trend
        self.skip = skip
        self.action_size = 3
        self.batch_size = batch_size
        self.memory = deque(maxlen = 1000)
        self.inventory = []

        self.gamma = 0.95
        self.epsilon = 0.5
        self.epsilon_min = 0.01
        self.epsilon_decay = 0.999

        tf.reset_default_graph()
        self.sess = tf.InteractiveSession()
        self.X = tf.placeholder(tf.float32, [None, self.state_size])
        self.Y = tf.placeholder(tf.float32, [None, self.action_size])
        feed = tf.layers.dense(self.X, 256, activation = tf.nn.relu)
        self.logits = tf.layers.dense(feed, self.action_size)
        self.cost = tf.reduce_mean(tf.square(self.Y - self.logits))
        self.optimizer = tf.train.GradientDescentOptimizer(1e-5).minimize(
            self.cost
        )
        self.sess.run(tf.global_variables_initializer())

    def act(self, state):
        if random.random() <= self.epsilon:
            return random.randrange(self.action_size)
        return np.argmax(
            self.sess.run(self.logits, feed_dict = {self.X: state})[0]
        )
    
    def get_state(self, t):
        window_size = self.window_size + 1
        d = t - window_size + 1
        block = self.trend[d : t + 1] if d >= 0 else -d * [self.trend[0]] + self.trend[0 : t + 1]
        res = []
        for i in range(window_size - 1):
            res.append(block[i + 1] - block[i])
        return np.array([res])

    def replay(self, batch_size):
        mini_batch = []
        l = len(self.memory)
        for i in range(l - batch_size, l):
            mini_batch.append(self.memory[i])
        replay_size = len(mini_batch)
        X = np.empty((replay_size, self.state_size))
        Y = np.empty((replay_size, self.action_size))
        states = np.array([a[0][0] for a in mini_batch])
        new_states = np.array([a[3][0] for a in mini_batch])
        Q = self.sess.run(self.logits, feed_dict = {self.X: states})
        Q_new = self.sess.run(self.logits, feed_dict = {self.X: new_states})
        for i in range(len(mini_batch)):
            state, action, reward, next_state, done = mini_batch[i]
            target = Q[i]
            target[action] = reward
            if not done:
                target[action] += self.gamma * np.amax(Q_new[i])
            X[i] = state
            Y[i] = target
        cost, _ = self.sess.run(
            [self.cost, self.optimizer], feed_dict = {self.X: X, self.Y: Y}
        )
        if self.epsilon > self.epsilon_min:
            self.epsilon *= self.epsilon_decay
        return cost
    
    def buy(self, initial_money):
        starting_money = initial_money
        states_sell = []
        states_buy = []
        inventory = []
        state = self.get_state(0)
        for t in range(0, len(self.trend) - 1, self.skip):
            action = self.act(state)
            next_state = self.get_state(t + 1)
            
            if action == 1 and initial_money >= self.trend[t] and t < (len(self.trend) - self.half_window):
                inventory.append(self.trend[t])
                initial_money -= self.trend[t]
                states_buy.append(t)
                print('day %d: buy 1 unit at price %f, total balance %f'% (t, self.trend[t], initial_money))
                
                
            elif action == 2 and len(inventory):
                bought_price = inventory.pop(0)
                initial_money += self.trend[t]
                states_sell.append(t)
                try:
                    invest = ((close[t] - bought_price) / bought_price) * 100
                except:
                    invest = 0
                print(
                    'day %d, sell 1 unit at price %f, investment %f %%, total balance %f,'
                    % (t, close[t], invest, initial_money)
                )
            
            state = next_state
        invest = ((initial_money - starting_money) / starting_money) * 100
        total_gains = initial_money - starting_money
        return states_buy, states_sell, total_gains, invest
        
    def train(self, iterations, checkpoint, initial_money):
        for i in range(iterations):
            total_profit = 0
            inventory = []
            state = self.get_state(0)
            starting_money = initial_money
            for t in range(0, len(self.trend) - 1, self.skip):
                action = self.act(state)
                next_state = self.get_state(t + 1)
                
                if action == 1 and starting_money >= self.trend[t] and t < (len(self.trend) - self.half_window):
                    inventory.append(self.trend[t])
                    starting_money -= self.trend[t]
                
                elif action == 2 and len(inventory) > 0:
                    bought_price = inventory.pop(0)
                    total_profit += self.trend[t] - bought_price
                    starting_money += self.trend[t]
                    
                invest = ((starting_money - initial_money) / initial_money)
                self.memory.append((state, action, invest, 
                                    next_state, starting_money < initial_money))
                state = next_state
                batch_size = min(self.batch_size, len(self.memory))
                cost = self.replay(batch_size)
            if (i+1) % checkpoint == 0:
                print('epoch: %d, total rewards: %f.3, cost: %f, total money: %f'%(i + 1, total_profit, cost,
                                                                                  starting_money))

# %%
close = df.Close.values.tolist()
initial_money = 10000
window_size = 30
skip = 1
batch_size = 32
agent = Agent(state_size = window_size, 
              window_size = window_size, 
              trend = close, 
              skip = skip, 
              batch_size = batch_size)
agent.train(iterations = 200, checkpoint = 10, initial_money = initial_money)
# Out:
# WARNING:tensorflow:From <ipython-input-3-9934fc4f9176>:26: dense (from tensorflow.python.keras.legacy_tf_layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.Dense instead.
# WARNING:tensorflow:From /Users/yutiansut/opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/keras/legacy_tf_layers/core.py:187: Layer.apply (from tensorflow.python.keras.engine.base_layer_v1) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.
# epoch: 10, total rewards: 422.365236.3, cost: 1.364079, total money: 10422.365236
# epoch: 20, total rewards: 534.935059.3, cost: 0.798562, total money: 10534.935059
# epoch: 30, total rewards: 602.345156.3, cost: 0.265015, total money: 10602.345156
# epoch: 40, total rewards: 566.065188.3, cost: 0.174696, total money: 10566.065188
# epoch: 50, total rewards: 587.645144.3, cost: 0.150241, total money: 10587.645144
# epoch: 60, total rewards: 783.955202.3, cost: 0.128209, total money: 10783.955202
# epoch: 70, total rewards: 649.345157.3, cost: 0.120099, total money: 10649.345157
# epoch: 80, total rewards: 497.855166.3, cost: 0.101619, total money: 10497.855166
# epoch: 90, total rewards: 758.275089.3, cost: 0.093407, total money: 10758.275089
# epoch: 100, total rewards: 636.745182.3, cost: 0.155615, total money: 10636.745182
# epoch: 110, total rewards: 568.735171.3, cost: 0.089497, total money: 10568.735171
# epoch: 120, total rewards: 446.655154.3, cost: 0.060618, total money: 10446.655154
# epoch: 130, total rewards: 514.755191.3, cost: 0.058627, total money: 10514.755191
# epoch: 140, total rewards: 526.815189.3, cost: 0.053542, total money: 10526.815189
# epoch: 150, total rewards: 516.935243.3, cost: 0.040972, total money: 10516.935243
# epoch: 160, total rewards: 447.525150.3, cost: 0.080917, total money: 10447.525150
# epoch: 170, total rewards: 467.815188.3, cost: 0.037493, total money: 10467.815188
# epoch: 180, total rewards: 651.705081.3, cost: 0.065774, total money: 10651.705081
# epoch: 190, total rewards: 407.905276.3, cost: 0.027556, total money: 10407.905276
# epoch: 200, total rewards: 537.245303.3, cost: 0.030553, total money: 10537.245303

# %%
states_buy, states_sell, total_gains, invest = agent.buy(initial_money = initial_money)
# Out:
# day 0: buy 1 unit at price 768.700012, total balance 9231.299988
# day 1, sell 1 unit at price 762.130005, investment -0.854691 %, total balance 9993.429993,
# day 6: buy 1 unit at price 762.559998, total balance 9230.869995
# day 10, sell 1 unit at price 764.479980, investment 0.251781 %, total balance 9995.349975,
# day 12: buy 1 unit at price 760.539978, total balance 9234.809997
# day 13: buy 1 unit at price 769.200012, total balance 8465.609985
# day 14: buy 1 unit at price 768.270020, total balance 7697.339965
# day 15, sell 1 unit at price 760.989990, investment 0.059170 %, total balance 8458.329955,
# day 16, sell 1 unit at price 761.679993, investment -0.977642 %, total balance 9220.009948,
# day 17, sell 1 unit at price 768.239990, investment -0.003909 %, total balance 9988.249938,
# day 19: buy 1 unit at price 758.039978, total balance 9230.209960
# day 20: buy 1 unit at price 747.919983, total balance 8482.289977
# day 21, sell 1 unit at price 750.500000, investment -0.994668 %, total balance 9232.789977,
# day 22, sell 1 unit at price 762.520020, investment 1.952085 %, total balance 9995.309997,
# day 24: buy 1 unit at price 771.190002, total balance 9224.119995
# day 25: buy 1 unit at price 776.419983, total balance 8447.700012
# day 26, sell 1 unit at price 789.289978, investment 2.347019 %, total balance 9236.989990,
# day 27, sell 1 unit at price 789.270020, investment 1.655037 %, total balance 10026.260010,
# day 32: buy 1 unit at price 794.200012, total balance 9232.059998
# day 33: buy 1 unit at price 796.419983, total balance 8435.640015
# day 34, sell 1 unit at price 794.559998, investment 0.045327 %, total balance 9230.200013,
# day 35, sell 1 unit at price 791.260010, investment -0.647896 %, total balance 10021.460023,
# day 40: buy 1 unit at price 771.820007, total balance 9249.640016
# day 42, sell 1 unit at price 786.900024, investment 1.953826 %, total balance 10036.540040,
# day 43: buy 1 unit at price 794.020020, total balance 9242.520020
# day 44, sell 1 unit at price 806.150024, investment 1.527670 %, total balance 10048.670044,
# day 45: buy 1 unit at price 806.650024, total balance 9242.020020
# day 46: buy 1 unit at price 804.789978, total balance 8437.230042
# day 47, sell 1 unit at price 807.909973, investment 0.156195 %, total balance 9245.140015,
# day 48: buy 1 unit at price 806.359985, total balance 8438.780030
# day 49, sell 1 unit at price 807.880005, investment 0.383954 %, total balance 9246.660035,
# day 51, sell 1 unit at price 806.070007, investment -0.035961 %, total balance 10052.730042,
# day 52: buy 1 unit at price 802.174988, total balance 9250.555054
# day 56, sell 1 unit at price 835.669983, investment 4.175522 %, total balance 10086.225037,
# day 66: buy 1 unit at price 808.380005, total balance 9277.845032
# day 67, sell 1 unit at price 809.559998, investment 0.145970 %, total balance 10087.405030,
# day 69: buy 1 unit at price 819.239990, total balance 9268.165040
# day 70: buy 1 unit at price 820.450012, total balance 8447.715028
# day 71: buy 1 unit at price 818.979980, total balance 7628.735048
# day 72, sell 1 unit at price 824.159973, investment 0.600555 %, total balance 8452.895021,
# day 73, sell 1 unit at price 828.070007, investment 0.928758 %, total balance 9280.965028,
# day 74, sell 1 unit at price 831.659973, investment 1.548267 %, total balance 10112.625001,
# day 76: buy 1 unit at price 831.330017, total balance 9281.294984
# day 77: buy 1 unit at price 828.640015, total balance 8452.654969
# day 79, sell 1 unit at price 823.210022, investment -0.976747 %, total balance 9275.864991,
# day 83, sell 1 unit at price 827.780029, investment -0.103783 %, total balance 10103.645020,
# day 84: buy 1 unit at price 831.909973, total balance 9271.735047
# day 85: buy 1 unit at price 835.369995, total balance 8436.365052
# day 86, sell 1 unit at price 838.679993, investment 0.813792 %, total balance 9275.045045,
# day 87, sell 1 unit at price 843.250000, investment 0.943295 %, total balance 10118.295045,
# day 88: buy 1 unit at price 845.539978, total balance 9272.755067
# day 90, sell 1 unit at price 847.200012, investment 0.196328 %, total balance 10119.955079,
# day 94: buy 1 unit at price 830.460022, total balance 9289.495057
# day 96: buy 1 unit at price 817.580017, total balance 8471.915040
# day 98, sell 1 unit at price 819.510010, investment -1.318548 %, total balance 9291.425050,
# day 99: buy 1 unit at price 820.919983, total balance 8470.505067
# day 100, sell 1 unit at price 831.409973, investment 1.691572 %, total balance 9301.915040,
# day 101: buy 1 unit at price 831.500000, total balance 8470.415040
# day 102: buy 1 unit at price 829.559998, total balance 7640.855042
# day 103, sell 1 unit at price 838.549988, investment 2.147591 %, total balance 8479.405030,
# day 104, sell 1 unit at price 834.570007, investment 0.369213 %, total balance 9313.975037,
# day 105, sell 1 unit at price 831.409973, investment 0.223007 %, total balance 10145.385010,
# day 108: buy 1 unit at price 824.729980, total balance 9320.655030
# day 113, sell 1 unit at price 836.820007, investment 1.465938 %, total balance 10157.475037,
# day 114: buy 1 unit at price 838.210022, total balance 9319.265015
# day 115: buy 1 unit at price 841.650024, total balance 8477.614991
# day 117, sell 1 unit at price 862.760010, investment 2.928859 %, total balance 9340.375001,
# day 118, sell 1 unit at price 872.299988, investment 3.641652 %, total balance 10212.674989,
# day 121: buy 1 unit at price 905.960022, total balance 9306.714967
# day 122: buy 1 unit at price 912.570007, total balance 8394.144960
# day 123: buy 1 unit at price 916.440002, total balance 7477.704958
# day 124: buy 1 unit at price 927.039978, total balance 6550.664980
# day 125, sell 1 unit at price 931.659973, investment 2.836764 %, total balance 7482.324953,
# day 128: buy 1 unit at price 932.169983, total balance 6550.154970
# day 131: buy 1 unit at price 932.219971, total balance 5617.934999
# day 132: buy 1 unit at price 937.080017, total balance 4680.854982
# day 133: buy 1 unit at price 943.000000, total balance 3737.854982
# day 134, sell 1 unit at price 919.619995, investment 0.772542 %, total balance 4657.474977,
# day 135: buy 1 unit at price 930.239990, total balance 3727.234987
# day 136: buy 1 unit at price 934.010010, total balance 2793.224977
# day 138, sell 1 unit at price 948.820007, investment 3.533238 %, total balance 3742.044984,
# day 139, sell 1 unit at price 954.960022, investment 3.011741 %, total balance 4697.005006,
# day 140, sell 1 unit at price 969.539978, investment 4.008925 %, total balance 5666.544984,
# day 141: buy 1 unit at price 971.469971, total balance 4695.075013
# day 142: buy 1 unit at price 975.880005, total balance 3719.195008
# day 143: buy 1 unit at price 964.859985, total balance 2754.335023
# day 145, sell 1 unit at price 975.599976, investment 4.653409 %, total balance 3729.934999,
# day 147: buy 1 unit at price 976.570007, total balance 2753.364992
# day 150, sell 1 unit at price 949.830017, investment 1.360610 %, total balance 3703.195009,
# day 151: buy 1 unit at price 942.900024, total balance 2760.294985
# day 152: buy 1 unit at price 953.400024, total balance 1806.894961
# day 154, sell 1 unit at price 942.309998, investment -0.073171 %, total balance 2749.204959,
# day 155, sell 1 unit at price 939.780029, investment 1.025546 %, total balance 3688.984988,
# day 156, sell 1 unit at price 957.369995, investment 2.501042 %, total balance 4646.354983,
# day 157, sell 1 unit at price 950.630005, investment -2.145199 %, total balance 5596.984988,
# day 158, sell 1 unit at price 959.450012, investment -1.683608 %, total balance 6556.435000,
# day 159, sell 1 unit at price 957.090027, investment -0.805294 %, total balance 7513.525027,
# day 161, sell 1 unit at price 952.270020, investment -2.488300 %, total balance 8465.795047,
# day 162, sell 1 unit at price 927.330017, investment -1.651289 %, total balance 9393.125064,
# day 164, sell 1 unit at price 917.789978, investment -3.735058 %, total balance 10310.915042,
# day 168: buy 1 unit at price 906.690002, total balance 9404.225040
# day 169, sell 1 unit at price 918.590027, investment 1.312469 %, total balance 10322.815067,
# day 175: buy 1 unit at price 953.419983, total balance 9369.395084
# day 176, sell 1 unit at price 965.400024, investment 1.256533 %, total balance 10334.795108,
# day 186: buy 1 unit at price 930.830017, total balance 9403.965091
# day 187, sell 1 unit at price 930.390015, investment -0.047270 %, total balance 10334.355106,
# day 189: buy 1 unit at price 927.960022, total balance 9406.395084
# day 190: buy 1 unit at price 929.359985, total balance 8477.035099
# day 191, sell 1 unit at price 926.789978, investment -0.126088 %, total balance 9403.825077,
# day 192, sell 1 unit at price 922.900024, investment -0.695098 %, total balance 10326.725101,
# day 195: buy 1 unit at price 922.669983, total balance 9404.055118
# day 197, sell 1 unit at price 926.960022, investment 0.464959 %, total balance 10331.015140,
# day 198: buy 1 unit at price 910.979980, total balance 9420.035160
# day 200, sell 1 unit at price 906.659973, investment -0.474215 %, total balance 10326.695133,
# day 202: buy 1 unit at price 927.000000, total balance 9399.695133
# day 203, sell 1 unit at price 921.280029, investment -0.617041 %, total balance 10320.975162,
# day 210: buy 1 unit at price 928.450012, total balance 9392.525150
# day 211: buy 1 unit at price 927.809998, total balance 8464.715152
# day 214, sell 1 unit at price 929.080017, investment 0.067856 %, total balance 9393.795169,
# day 215: buy 1 unit at price 932.070007, total balance 8461.725162
# day 217: buy 1 unit at price 925.109985, total balance 7536.615177
# day 218: buy 1 unit at price 920.289978, total balance 6616.325199
# day 219, sell 1 unit at price 915.000000, investment -1.380670 %, total balance 7531.325199,
# day 220, sell 1 unit at price 921.809998, investment -1.100777 %, total balance 8453.135197,
# day 221, sell 1 unit at price 931.580017, investment 0.699380 %, total balance 9384.715214,
# day 222, sell 1 unit at price 932.450012, investment 1.321326 %, total balance 10317.165226,
# day 223: buy 1 unit at price 928.530029, total balance 9388.635197
# day 224: buy 1 unit at price 920.969971, total balance 8467.665226
# day 225, sell 1 unit at price 924.859985, investment -0.395253 %, total balance 9392.525211,
# day 226, sell 1 unit at price 944.489990, investment 2.553831 %, total balance 10337.015201,
# day 227: buy 1 unit at price 949.500000, total balance 9387.515201
# day 228, sell 1 unit at price 959.109985, investment 1.012110 %, total balance 10346.625186,
# day 229: buy 1 unit at price 953.270020, total balance 9393.355166
# day 230: buy 1 unit at price 957.789978, total balance 8435.565188
# day 231: buy 1 unit at price 951.679993, total balance 7483.885195
# day 233, sell 1 unit at price 978.890015, investment 2.687591 %, total balance 8462.775210,
# day 234, sell 1 unit at price 977.000000, investment 2.005661 %, total balance 9439.775210,
# day 235: buy 1 unit at price 972.599976, total balance 8467.175234
# day 236: buy 1 unit at price 989.250000, total balance 7477.925234
# day 238, sell 1 unit at price 989.679993, investment 3.992939 %, total balance 8467.605227,
# day 239, sell 1 unit at price 992.000000, investment 1.994656 %, total balance 9459.605227,
# day 240, sell 1 unit at price 992.179993, investment 0.296183 %, total balance 10451.785220,

# %%
fig = plt.figure(figsize = (15,5))
plt.plot(close, color='r', lw=2.)
plt.plot(close, '^', markersize=10, color='m', label = 'buying signal', markevery = states_buy)
plt.plot(close, 'v', markersize=10, color='k', label = 'selling signal', markevery = states_sell)
plt.title('total gains %f, total investment %f%%'%(total_gains, invest))
plt.legend()
plt.show()
